# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/game_data')

# %%
df[df.away=='TEN']
# Out:
#       Unnamed: 0 away  away_score  \
# 0              0  TEN          10
# 43             0  TEN          17
# 52             0  TEN          17
# 86             0  TEN           0
# 126            0  TEN          34
# 159            0  TEN          20
# 181            0  TEN          17
# 255            0  TEN          17
# 288            0  TEN          29
# 328            0  TEN          34
# 345            0  TEN          30
# 367            0  TEN          25
# 387            0  TEN          17
# 421            0  TEN           0
# 485            0  TEN          14
# 501            0  TEN          20
# 516            0  TEN          14
# 561            0  TEN          31
# 576            0  TEN          17
# 644            0  TEN          30
# 660            0  TEN          17
# 691            0  TEN          23
# 724            0  TEN          13
# 756            0  TEN          23
# 796            0  TEN          10
# 818            0  TEN          14
# ...
